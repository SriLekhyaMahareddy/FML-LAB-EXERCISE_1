# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
#load data
data= pd.read_csv("Company_data.csv")
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
#EDA
data.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
data.shape
# Out:
# (200, 4)

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
#Create feature and target array from such given data
X=data.drop('Sales',axis=1).values
y=data['Sales'].values

# %%
X.shape,y.shape
# Out:
# ((200, 3), (200,))

# %%
y=y.reshape(-1,1)

# %%
#Fitting a regression model
reg = linear_model.LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,train_size=0.7)

# %%
X_train.shape,y_train.shape
# Out:
# ((140, 3), (140, 1))

# %%
#Evaluating the model on training data only
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
y_train_pred = reg.predict(X_train)

print(f'MAE = {mean_absolute_error(y_train, y_train_pred)}')
print(f'MSE = {mean_squared_error(y_train, y_train_pred)}')
print(f'RMSE = {np.sqrt(mean_squared_error(y_train, y_train_pred))}')
print(f'R_2 = {r2_score(y_train, y_train_pred)}')
# Out:
# MAE = 1.3259948292720696
# MSE = 3.0886839855279375
# RMSE = 1.7574652160221942
# R_2 = 0.8872079789875922

# %%
#Evaluating the model on testing data only
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
y_test_pred = reg.predict(X_test)

print(f'MAE = {mean_absolute_error(y_test, y_test_pred)}')
print(f'MSE = {mean_squared_error(y_test, y_test_pred)}')
print(f'RMSE = {np.sqrt(mean_squared_error(y_test, y_test_pred))}')
print(f'R_2 = {r2_score(y_test, y_test_pred)}')
# Out:
# MAE = 1.027318713017787
# MSE = 1.813091192525865
# RMSE = 1.3465107472745492
# R_2 = 0.9319832906113035
